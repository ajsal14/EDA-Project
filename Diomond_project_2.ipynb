# %% [markdown]
# **The dataset appears to contain information about diamonds, with each row representing an individual diamond. Here are the columns:**

# %% [markdown]
# 1. carat: The weight of the diamond.
# 2. cut: The quality of the diamond cut (e.g., Ideal, Premium, Good).
# 3. color: The color grade of the diamond, with a range from D (best) to J (lowest).
# 4. clarity: The clarity grade, indicating the presence of inclusions or blemishes (e.g., SI1, VS1).
# 5. depth: The depth percentage, calculated as depth / width.
# 6. table: The width of the diamond’s top surface relative to its widest point.
# 7. price: The price of the diamond in dollars.
# 8. x: Length of the diamond in millimeters.
# 9. y: Width of the diamond in millimeters.
# 10. z: Depth of the diamond in millimeters.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diamonds.csv')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %% [markdown]
# # 1.Understand the Data

# %%
df.shape
# Out:
# (50000, 10)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.799444     61.753006     57.457830   3944.805440      5.734403
# std        0.475173      1.431088      2.232092   3997.938105      1.123077
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    951.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2410.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5351.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  50000.000000  50000.000000
# mean       5.737956      3.541056
# std        1.145579      0.707065
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    50000 non-null  float64
#  1   cut      50000 non-null  object
#  2   color    50000 non-null  object
#  3   clarity  50000 non-null  object
#  4   depth    50000 non-null  float64
#  5   table    50000 non-null  float64
#  6   price    50000 non-null  int64
#  7   x        50000 non-null  float64
#  8   y        50000 non-null  float64
#  9   z        50000 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.8+ MB

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        19938
# Premium      12806
# Very Good    11204
# Good          4557
# Fair          1495
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    10452
# E     9085
# F     8864
# H     7711
# D     6224
# I     5058
# J     2606
# Name: count, dtype: int64

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     12115
# VS2     11404
# SI2      8519
# VS1      7579
# VVS2     4694
# VVS1     3369
# IF       1632
# I1        688
# Name: count, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (49874, 10)

# %%
missing_values=df.isnull().sum()
print(missing_values)
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# # descriptive statistics

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  49874.000000  49874.000000  49874.000000  49874.000000  49874.000000
# mean       0.556058     61.751803     57.458786   3945.384569      5.734441
# std        0.245026      1.428207      2.231087   3996.939331      1.122340
# min        0.182322     43.000000     43.000000    326.000000      0.000000
# 25%        0.336472     61.000000     56.000000    952.000000      4.720000
# 50%        0.530628     61.800000     57.000000   2414.000000      5.700000
# 75%        0.712950     62.500000     59.000000   5352.000000      6.540000
# max        1.793425     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  49874.000000  49874.000000
# mean       5.738060      3.541028
# std        1.144973      0.706607
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.describe(include="all")
# Out:
#                carat      cut  color clarity         depth         table  \
# count   49874.000000  49874.0  49874   49874  49874.000000  49874.000000
# unique           NaN      5.0      7       8           NaN           NaN
# top              NaN      0.0      G     SI1           NaN           NaN
# freq             NaN  19881.0  10424   12086           NaN           NaN
# mean        0.556058      NaN    NaN     NaN     61.751803     57.458786
# std         0.245026      NaN    NaN     NaN      1.428207      2.231087
# min         0.182322      NaN    NaN     NaN     43.000000     43.000000
# 25%         0.336472      NaN    NaN     NaN     61.000000     56.000000
# 50%         0.530628      NaN    NaN     NaN     61.800000     57.000000
# 75%         0.712950      NaN    NaN     NaN     62.500000     59.000000
# max         1.793425      NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# ...

# %% [markdown]
# # Visualization

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
plt.figure(figsize=(12,8))

sns.barplot(x="cut", y="carat", data=df, hue="clarity")

plt.show()

# %%
df.hist(color='lightblue',edgecolor='black',figsize=(20,10),bins=10)
plt.suptitle('Histogram of dataframe', fontsize=20)
plt.show()

# %% [markdown]
# # data correlation

# %%
df
# Out:
#           carat      cut color clarity  depth  table  price     x     y     z
# 0      0.207014        0     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1      0.190620  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2      0.207014        3     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3      0.254642  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4      0.270027        3     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...         ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995  0.542324        0     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996  0.542324        3     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997  0.530628        2     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998  0.620576  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999  0.559616        0     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
df.value_counts(df["cut"])
# Out:
# cut
# 0          19881
# Premium    12769
# 2          11194
# 3           4547
# 4           1483
# Name: count, dtype: int64

# %%
df.value_counts(df["color"])
# Out:
# color
# G    10424
# E     9067
# F     8844
# H     7683
# D     6209
# I     5045
# J     2602
# Name: count, dtype: int64

# %%
df.value_counts(df["clarity"])
# Out:
# clarity
# SI1     12086
# VS2     11378
# SI2      8483
# VS1      7564
# VVS2     4687
# VVS1     3363
# IF       1626
# I1        687
# Name: count, dtype: int64

# %%
df["cut"].replace(["Ideal","Premium","Very Good","Good","Fair"],[0,1,2,3,4],inplace=True)

df["color"].replace(["G","E","F","H","D","I","J"],[0,1,2,3,4,5,6],inplace=True)

df["clarity"].replace(["SI1","VS2","SI2","VS1","VVS2","VVS1","IF","I1"],[0,1,2,3,4,5,6,7],inplace=True)
# Out:
# <ipython-input-44-599b85e9612f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cut"].replace(["Ideal","Premium","Very Good","Good","Fair"],[0,1,2,3,4],inplace=True)
# <ipython-input-44-599b85e9612f>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df
# Out:
#           carat  cut  color  clarity  depth  table  price     x     y     z
# 0      0.207014    0      1        2   61.5   55.0    326  3.95  3.98  2.43
# 1      0.190620    1      1        0   59.8   61.0    326  3.89  3.84  2.31
# 2      0.207014    3      1        3   56.9   65.0    327  4.05  4.07  2.31
# 3      0.254642    1      5        1   62.4   58.0    334  4.20  4.23  2.63
# 4      0.270027    3      6        2   63.3   58.0    335  4.34  4.35  2.75
# ...         ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 49995  0.542324    0      4        0   60.8   57.0   2757  5.75  5.76  3.50
# 49996  0.542324    3      4        0   63.1   55.0   2757  5.69  5.75  3.61
# 49997  0.530628    2      4        0   62.8   60.0   2757  5.66  5.68  3.56
# 49998  0.620576    1      3        2   61.0   58.0   2757  6.15  6.12  3.74
# 49999  0.559616    0      4        2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49874 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    49874 non-null  float64
#  1   cut      49874 non-null  int64
#  2   color    49874 non-null  int64
#  3   clarity  49874 non-null  int64
#  4   depth    49874 non-null  float64
#  5   table    49874 non-null  float64
#  6   price    49874 non-null  int64
#  7   x        49874 non-null  float64
#  8   y        49874 non-null  float64
#  9   z        49874 non-null  float64
# dtypes: float64(6), int64(4)
# memory usage: 4.2 MB

# %%
Corr_matrix = df.corr()

sns.heatmap(Corr_matrix,annot=True, fmt='0.01f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
Corr_matrix = df.corr()['price']

sns.heatmap(Corr_matrix.to_frame(), annot=True, fmt='.2f', cmap='coolwarm',
            cbar=True, annot_kws={'size': 10})
# Out:
# <Axes: >

# %%
Corr_matrix
# Out:
# carat      0.902383
# cut        0.052303
# color      0.091614
# clarity   -0.081848
# depth     -0.013112
# table      0.129283
# price      1.000000
# x          0.884844
# y          0.864232
# z          0.860791
# Name: price, dtype: float64

# %%
# droping less correlated features

# %% [markdown]
# # Skewness detection

# %%
df
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23        0     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23        3     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31        3     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72        0     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72        3     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70        2     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75        0     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %% [markdown]
# ## carat

# %%
sns.histplot(df['carat'],bins=30, kde=True)
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %%
df['carat'] = np.log1p(df['carat'])
sns.histplot(df['carat'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ## cut

# %%
sns.histplot(df['cut'],bins=30, kde=True)
# Out:
# <Axes: xlabel='cut', ylabel='Count'>

# %%
df['cut'] = np.log1p(df['cut'])
sns.histplot(df['cut'],bins=30, kde=True)
plt.show()

# %%
sns.histplot(df['color'],bins=30, kde=True)
plt.show()

# %%
df['color'] = np.log1p(df['color'])
sns.histplot(df['color'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ## table

# %%
sns.histplot(df['table'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ## x

# %%
sns.histplot(df['x'],bins=30, kde=True)
plt.show()

# %%
df['x'] = np.log1p(df['x'])
sns.histplot(df['x'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ## y

# %%
sns.histplot(df['y'],bins=30, kde=True)
plt.show()

# %%
df['y'] = np.log1p(df['y'])
sns.histplot(df['y'],bins=30, kde=True)
plt.show()

# %% [markdown]
# ## z

# %%
sns.histplot(df['z'],bins=30, kde=True)
plt.show()

# %%
df['z'] = np.log1p(df['z'])
sns.histplot(df['z'],bins=30, kde=True)
plt.show()

# %% [markdown]
# # outlier detection

# %%
df
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23        0     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23        3     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31        3     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72        0     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72        3     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70        2     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75        0     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [49874 rows x 10 columns]

# %%
sns.boxplot(x=df['carat'])


# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['carat']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in carat: {outliers2.shape[0]}')
# Out:
# Number of outliers in carat: 381

# %%
sns.boxplot(x=df['cut'])
plt.show()

# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['cut']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in cut: {outliers2.shape[0]}')
# Out:
# Number of outliers in cut: 0

# %%
sns.boxplot(x=df['table'])
plt.show()

# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['table']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in table: {outliers2.shape[0]}')
# Out:
# Number of outliers in table: 306

# %%
sns.boxplot(x=df['price'])
plt.show()

# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['price']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in price: {outliers2.shape[0]}')
# Out:
# Number of outliers in price: 1097

# %%
sns.boxplot(x=df['price'])
plt.show()

# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['price']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in price: {outliers2.shape[0]}')
# Out:
# Number of outliers in price: 1097

# %%
sns.boxplot(x=df['x'])
plt.show()

# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['x']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in x: {outliers2.shape[0]}')
# Out:
# Number of outliers in x: 13

# %%
sns.boxplot(x=df['y'])
plt.show()

# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['y']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in y: {outliers2.shape[0]}')
# Out:
# Number of outliers in y: 13

# %%
sns.boxplot(x=df['z'])
plt.show()

# Z-score to detect outliers
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['z']))
outliers2 = df[z_scores > 3]
print(f'Number of outliers in z: {outliers2.shape[0]}')
# Out:
# Number of outliers in z: 31

# %% [markdown]
# ## Removing outliers

# %%
df.shape
# Out:
# (49874, 10)

# %%
# Function to remove outliers using the IQR method except for one column
def remove_outliers_iqr(df, exclude_column):
    for col in df.columns:
        # Skip the specified column
        if col == exclude_column:
            continue
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Filter the DataFrame to remove rows with outliers in each column
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Specify the column to exclude
df_cleaned = remove_outliers_iqr(df, exclude_column='price')
df_cleaned
# Out:
#           carat       cut     color   clarity  depth  table  price         x  \
# 0      0.207014  0.000000  0.526589  1.098612   61.5   55.0    326  1.599388
# 1      0.190620  0.693147  0.526589  0.000000   59.8   61.0    326  1.587192
# 3      0.254642  0.693147  1.026672  0.693147   62.4   58.0    334  1.648659
# 4      0.270027  1.386294  1.080418  1.098612   63.3   58.0    335  1.675226
# 5      0.215111  1.098612  1.080418  1.609438   62.8   57.0    336  1.597365
# ...         ...       ...       ...       ...    ...    ...    ...       ...
# 49995  0.542324  0.000000  0.959135  0.000000   60.8   57.0   2757  1.909543
# 49996  0.542324  1.386294  0.959135  0.000000   63.1   55.0   2757  1.900614
# 49997  0.530628  1.098612  0.959135  0.000000   62.8   60.0   2757  1.896119
# 49998  0.620576  0.693147  0.869742  1.098612   61.0   58.0   2757  1.967112
# 49999  0.559616  0.000000  0.959135  1.098612   62.2   55.0   2757  1.921325
#
#               y         z
# ...

# %%
df.shape
# Out:
# (49874, 10)

# %% [markdown]
# # feature engineering

# %% [markdown]
# - we have already done feature engineering in data correlation

# %% [markdown]
# 1. carat: The weight of the diamond.
# 2. cut: The quality of the diamond cut (e.g., Ideal, Premium, Good).
# 3. color: The color grade of the diamond, with a range from D (best) to J (lowest).
# 4. clarity: The clarity grade, indicating the presence of inclusions or blemishes (e.g., SI1, VS1).
# 5. depth: The depth percentage, calculated as depth / width.
# 6. table: The width of the diamond’s top surface relative to its widest point.
# 7. price: The price of the diamond in dollars.
# 8. x: Length of the diamond in millimeters.
# 9. y: Width of the diamond in millimeters.
# 10. z: Depth of the diamond in millimeters.

# %%
df['price_per_carat'] = df['price'] / df['carat']

# %%
df['volume'] = df['x'] * df['y'] * df['z']
